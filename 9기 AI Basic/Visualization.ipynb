# %% [markdown]
# # matplotlib
# - pyplot 객체를 사용하여 데이터를 표시
# - pyplot 객체에 그래프들을 쌓은 다음 show로 flush

# %%
import matplotlib.pyplot as plt

X=range(100)
Y=[value**2 for value in X]
plt.plot(X,Y) # plot: 선 그래프
plt.show()

# %% [markdown]
# - 최대 단점 argument를 kwargs 받음
# - 고정된 argument가 없어서 `alt+tab` 으로 확인이 어려움

# %% [markdown]
# - Graph는 원래 figure 객체에 생성됨
# - pyplot 객체 사용시, 기보 figure에 그래프가 그려짐

# %%
import numpy as np

# %%
X_1=range(100)
Y_1=[np.cos(value) for value in X]

X_2=range(100)
Y_2=[np.sin(value) for value in X]

plt.plot(X_1, Y_1)
plt.plot(X_2, Y_2)
plt.show()

# %%
fig=plt.figure() # figure 반환
fig.set_size_inches(10,5) # 크기 지정
ax_1=fig.add_subplot(1,2,1) # 두 개의 plot 생성
ax_2=fig.add_subplot(1,2,2)

ax_1.plot(X_1, Y_1, c='b')
ax_2.plot(X_2, Y_2, c='g')
plt.show() # show & flush

# %% [markdown]
# ## Set color
# - color 속성을 사용
# - Float → 흑백, rgb color, predefined color 사용

# %%
plt.plot(X_1, Y_1, color='#eeefff') # color
plt.plot(X_2, Y_2, color='r')

plt.show()

# %% [markdown]
# ## Set linestyle
# - ls 또는 linestyle 속성 사용

# %%
plt.plot(X_1, Y_1, color='b', linestyle='dashed') # linestyle
plt.plot(X_2, Y_2, color='r', ls='dotted')

plt.show()

# %% [markdown]
# ## Set title
# - pyplot에 title 함수 사용, figure의 subplot별 입력 가능

# %%
plt.plot(X_1, Y_1, color='b', linestyle='dashed')
plt.plot(X_2, Y_2, color='r', ls='dotted')

plt.title('Two lines') # title
plt.show()

# %% [markdown]
# - Latex 타입의 표현도 가능(수식 표현 가능)

# %%
plt.title('$y=\\frac{ax+b}{test}$')
plt.show()

# %% [markdown]
# ## Set legend
# - legend 함수로 범례를 표시함, loc 위치 등 속성 지정

# %%
plt.plot(X_1, Y_1, color='b', linestyle='dashed', label='line_1') # label
plt.plot(X_2, Y_2, color='r', ls='dotted', label='line_2')

plt.legend(shadow=True, fancybox=True, loc='lower right') # legend
plt.show()

# %% [markdown]
# # Scatter
# - scater 함수 사용

# %% [markdown]
# - marker: scatter 모양 지정
# - s: 데이터의 크기를 지정, 데이터의 크기 비교 가능

# %%
data_1=np.random.rand(512,2)
data_2=np.random.rand(512,2)

plt.scatter(data_1[:,0], data_1[:,1], c='b', marker='x') # marker
plt.scatter(data_2[:,0], data_2[:,1], c='r', marker='^')

plt.show()

# %%
N=50
x=np.random.rand(N)
y=np.random.rand(N)
colors=np.random.rand(N)
area=np.pi * (15 * np.random.rand(N)) ** 2

plt.scatter(x, y, s=area, c=colors, alpha=0.5) # s: 데이터의 크기
plt.show()

# %% [markdown]
# # Bar chart
# - bar 함수 사용

# %%
data=[[5., 25., 50., 20.],
      [4., 23., 51., 17],
      [6., 22., 52., 19]]

X=np.arange(4)

plt.bar(X+0.00, data[0], color='b', width=0.25) # bar
plt.bar(X+0.25, data[1], color='g', width=0.25)
plt.bar(X+0.50, data[2], color='r', width=0.25)
plt.xticks(X+0.25, ('A','B','C','D'))
plt.show()

# %%
data=np.array([[5., 25., 50., 20.],
              [4., 23., 51., 17],
              [6., 22., 52., 19]])

color_list=['b','g','r']
data_label=['A','B','C']

X=np.arange(data.shape[1])

for i in range(data.shape[0]):
    plt.bar(X, data[i], bottom=np.sum(data[:i], axis=0),
                                color=color_list[i], label=data_label[i]) # bar
plt.legend()
plt.show()

# %% [markdown]
# # histogram

# %%
X=np.random.randn(1000)
plt.hist(X, bins=100) # bins: 구간의 개수
plt.show()

# %% [markdown]
# # boxplot

# %%
data=np.random.randn(100,5)
plt.boxplot(data) # boxplot
plt.show()

# %% [markdown]
# # Pandas matplotlib
# - pandas 0.7버전 이상부터 matplotlib를 사용한 그래프 지원
# - Dataframe, series 별로 그래프 작성 가능
# - 데이터간의 상관관계를 볼 때 scatter graph 사용 가능

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data_url = 'housing.csv'
df_data = pd.read_csv(data_url, sep=',', header = 0) #csv 타입 데이터 로드, separate는 콤마(,) 지정하고, Column은 0번 행
df_data.columns = ['CRIM','ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO' ,'B', 'LSTAT', 'MEDV'] # Column Header 이름 지정
df_data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
fig = plt.figure()
ax = []
for i in range(1,5):
    ax.append(fig.add_subplot(2,2,i))
    
ax[0].scatter(df_data["CRIM"], df_data["MEDV"])
ax[1].scatter(df_data["PTRATIO"], df_data["MEDV"])
ax[2].scatter(df_data["AGE"], df_data["MEDV"])
ax[3].scatter(df_data["NOX"], df_data["MEDV"])
plt.show()

# %% [markdown]
# - matplotlib의 꾸미기 함수 그대로 사용함

# %%
fig=plt.figure()
fig.set_size_inches(10.0, 10.0, forward=True)
ax=[]

for i in range(1,5):
    ax.append(fig.add_subplot(2,2,i))

ax[0].scatter(df_data['CRIM'],df_data['MEDV'], color='b',label='CRIM') # color, label
ax[1].scatter(df_data['PTRATIO'],df_data['MEDV'], color='g') # color
ax[2].scatter(df_data['AGE'],df_data['MEDV'])
ax[3].scatter(df_data['NOX'],df_data['MEDV'])

plt.subplots_adjust(wspace=0, hspace=0)
ax[0].legend()
ax[0].set_title('CRIM')

plt.show()

# %%
fig = plt.figure()
fig.set_size_inches(5,5)

ax_1 = fig.add_subplot(1,2,1)
ax_2 = fig.add_subplot(1,2,2)

ax_1.plot(df_data["MEDV"])
ax_2.hist(df_data["MEDV"], bins=50)

ax_1.set_title("House price MEDV")
ax_2.set_title("House price MEDV")

plt.show()

# %% [markdown]
# # Scaled boxplot

# %%
from sklearn.preprocessing import StandardScaler

std_scaler=StandardScaler()

scale_data=std_scaler.fit_transform(df_data)

fig=plt.figure()
ax=fig.add_subplot(1,1,1)

ax.boxplot(scale_data, labels=df_data.columns) # boxplot

fig.set_size_inches(18.5, 10.5)

plt.show()

# %% [markdown]
# # Scatter matrix

# %%
pd.plotting.scatter_matrix(df_data, diagonal='kde', alpha=1, figsize=(20,20))
plt.show()

# %%
corr_data = np.corrcoef(scale_data.T[:5])
corr_data
# Out:
# array([[ 1.        , -0.20046922,  0.40658341, -0.05589158,  0.42097171],
#        [-0.20046922,  1.        , -0.53382819, -0.04269672, -0.51660371],
#        [ 0.40658341, -0.53382819,  1.        ,  0.06293803,  0.76365145],
#        [-0.05589158, -0.04269672,  0.06293803,  1.        ,  0.09120281],
#        [ 0.42097171, -0.51660371,  0.76365145,  0.09120281,  1.        ]])

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
cax=ax.matshow(corr_data, vmin=-1, vmax=1, interpolation='nearest')
fig.colorbar(cax)
fig.set_size_inches(10,10)
ticks=np.arange(0,5,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)

ax.set_xticklabels(df_data.columns[:5])
ax.set_yticklabels(df_data.columns[:5])
# Out:
# [Text(0, 0, 'CRIM'),
#  Text(0, 1, 'ZN'),
#  Text(0, 2, 'INDUS'),
#  Text(0, 3, 'CHAS'),
#  Text(0, 4, 'NOX')]
